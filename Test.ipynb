# %%
import tushare as ts
import os
import datetime
import pymongo
import pandas

client = pymongo.MongoClient("127.0.0.1", 27017)
today = datetime.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)

# %%
cs = []
for c in client.Common.Concept.find({}):
    cs.append(c)
    print c["name"]
    
print(pandas.DataFrame(cs))
# Out:
# 生物育种
# 固废处理
# 婴童概念
# 业绩预升
# QFII重仓
# 风能
# 可燃冰
# 电子支付
# 聚氨酯
# 新零售
# 含可转债
# 稀缺资源
# 国产软件
# 超级细菌
# 氢燃料
# 丝绸之路
# 东亚自贸
# 循环经济
# 低碳经济
# 基金重仓
# 央企50
# 智能交通
# 抗癌
# 海工装备
# 上海自贸
# 深圳本地
# 股期概念
# 博彩概念
# 免疫治疗
# 振兴沈阳
# 风沙治理
# 智能机器
# 稀土永磁
# 送转潜力
# 多晶硅
# 三沙概念
# 重组概念
# 上海本地
# 三网融合
# 出口退税
# 迪士尼
# 武汉规划
# 基因芯片
# IPV6概念
# 长株潭
# 水利建设
# 皖江区域
# 海水淡化
# 摘帽概念
# 前海概念
# 电商概念
# 自贸区
# 天津自贸
# 核电核能
# 页岩气
# 粤港澳
# 食品安全
# 空气治理
# 猪肉
# 准ST股
# 充电桩
# 汽车电子
# 养老概念
# 奢侈品
# 高校背景
# O2O模式
# 融资融券
# 绿色照明
# 创投概念
# 机器人概念
# 装饰园林
# 基因测序
# 信息安全
# 含B股
# 草甘膦
# 内贸规划
# 新三板
# 网络游戏
# 沿海发展
# 维生素
# 社保重仓
# 污水处理
# 节能环保
# 基因概念
# 券商重仓
# 黄金概念
# 超导概念
# 本月解禁
# 触摸屏
# 苹果概念
# 业绩预降
# 5G概念
# 保障房
# 京津冀
# 智能穿戴
# 金融改革
# 生物质能
# 新能源
# 燃料电池
# 蓝宝石
# 智能电网
# 陕甘宁
# 涉矿概念
# 雄安新区
# 建筑节能
# 特斯拉
# 地热能
# 军工航天
# 信托重仓
# 太阳能
# 卫星导航
# 云计算
# 分拆上市
# 海峡西岸
# 赛马概念
# 外资背景
# 保险重仓
# 整体上市
# 含H股
# 水域改革
# 股权激励
# 生物燃料
# 文化振兴
# 军民融合
# 成渝特区
# IP变现
# 民营医院
# 民营银行
# 体育概念
# 甲型流感
# 资产注入
# 海上丝路
# 物联网
# 风能概念
# 安防服务
# 互联金融
# 3D打印
# 锂电池
# ST板块
# 石墨烯
# 碳纤维
# 阿里概念
# 铁路基建
# 生态农业
# 4G概念
# 黄河三角
# 金融参股
# ...
